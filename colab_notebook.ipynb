# %% [markdown]
# <a href="https://colab.research.google.com/github/osherBZ2404/newRepo/blob/main/colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Wed May 29 08:00:56 2024

# %%
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# colab_notebook.ipynb

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
name = 'Cloud course'
variable_name = "" # @param {type:"string"}

#@title Date fields
date_input = '2024-05-29'
print(date_input)
# Out:
# 2024-05-29

# %%
# @title Default title text
form = 59 # @param {type:"slider", min:0, max:100, step:1}
